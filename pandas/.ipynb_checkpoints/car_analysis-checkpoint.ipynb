# %%
import os
import math
import sympy as sp
import numpy as np
import pandas as pd

# %%
path = os.path.join('cardata.csv')
df = pd.read_csv(path, encoding='latin1')

# %%
df.head()
# Out:
#   Company Names     Cars Names      Engines CC/Battery Capacity HorsePower  \
# 0       FERRARI  SF90 STRADALE           V8             3990 cc     963 hp
# 1   ROLLS ROYCE        PHANTOM          V12             6749 cc     563 hp
# 2          Ford            KA+  1.2L Petrol            1,200 cc   70-85 hp
# 3      MERCEDES        GT 63 S           V8            3,982 cc     630 hp
# 4          AUDI     AUDI R8 Gt          V10            5,204 cc     602 hp
#
#   Total Speed Performance(0 - 100 )KM/H      Cars Prices       Fuel Types  \
# 0    340 km/h                   2.5 sec      $1,100,000   plug in hyrbrid
# 1    250 km/h                   5.3 sec        $460,000            Petrol
# 2    165 km/h                  10.5 sec  $12,000-$15,000           Petrol
# 3    250 km/h                   3.2 sec        $161,000            Petrol
# 4    320 km/h                   3.6 sec        $253,290            Petrol
#
#   Seats        Torque
# 0     2        800 Nm
# 1     5        900 Nm
# ...

# %%
df.shape[0]
# Out:
# 1218

# %%
df['Company Names'].value_counts().get('Ford')
# Out:
# 54

# %%
df[df['Company Names'] == 'Toyota'][['Engines', 'HorsePower']]
# Out:
#                                  Engines    HorsePower
# 1213                      2.5L Hybrid I4        240 hp
# 1214  2.4L Turbo I4 (i-FORCE MAX Hybrid)        326 hp
# 1215              2.0L Gas / 2.0L Hybrid  169  196 hp
# 1216                  1.8L / 2.0L Hybrid  140  198 hp
# 1217        2.5L Hybrid / Plug-in Hybrid  219  302 hp

# %%
pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rowwidth', None)
df
# Out:
#           Company Names                               Cars Names  \
# 0               FERRARI                            SF90 STRADALE
# 1           ROLLS ROYCE                                  PHANTOM
# 2                  Ford                                      KA+
# 3              MERCEDES                                  GT 63 S
# 4                  AUDI                               AUDI R8 Gt
# 5                   BMW                             Mclaren 720s
# 6          ASTON MARTIN                               VANTAGE F1
# 7               BENTLEY                     Continental GT Azure
# 8           LAMBORGHINI                          VENENO ROADSTER
# 9               FERRARI                               F8 TRIBUTO
# 10              FERRARI                                  812 GTS
# 11              FERRARI                                PORTOFINO
# 12              FERRARI                                     ROMA
# ...

# %%
df['CC/Battery Capacity'].isnull().sum()
# Out:
# 3

# %%
df['CC/Battery Capacity'].str.len().value_counts().sum()
# Out:
# 1215

# %%
df['CC/Battery Capacity'].str.len().value_counts()
# Out:
# CC/Battery Capacity
# 8.0     534
# 7.0     486
# 6.0      58
# 16.0     34
# 12.0     25
# 17.0     23
# 34.0     15
# 13.0     10
# 27.0      9
# 19.0      4
# 14.0      3
# 21.0      3
# 23.0      2
# 1.0       2
# 18.0      1
# 24.0      1
# 47.0      1
# 29.0      1
# 48.0      1
# 25.0      1
# 11.0      1
# Name: count, dtype: int64

# %%
df[df['CC/Battery Capacity'].str.contains('kWh', na=False)]
# Out:
#           Company Names                          Cars Names  \
# 271          Volkswagen                                Golf
# 277          Volkswagen                                ID.4
# 278          Volkswagen                                 Up!
# 289          Volkswagen                                ID.3
# 290          Volkswagen                            ID. Buzz
# 297          Volkswagen                                ID.5
# 298          Volkswagen                      ID. Buzz Cargo
# 307          Volkswagen                            ID.4 GTX
# 308          Volkswagen                            ID.3 Pro
# 320          Volkswagen                       Golf Electric
# 329          Volkswagen                                ID.2
# 335          Volkswagen                          ID.4 Pro S
# 347          Volkswagen                        ID. Buzz Pro
# 355          Volkswagen                            ID.3 GTX
# 366          Volkswagen                  ID. Buzz Cargo Pro
# ...

# %%
df['Engines'].value_counts().sort_index()
# Out:
# Engines
# 0.36L Inline-2                                     1
# 0.66L Inline-3                                     1
# 0.7L 3-Cylinder                                    5
# 1.0L EcoBoost / 1.5L                               1
# 1.0L EcoBoost / 1.5L / 2.0L                        1
# 1.0L I3 Turbo                                      2
# 1.0L I3 Turbo / 1.5L I4 Turbo                      2
# 1.0L Inline-2 (Wankel)                             1
# 1.0L Turbo I3                                      1
# 1.0L Turbo I3 / 1.5L Turbo I4                      1
# 1.0L Turbo I3 / 1.6L Diesel                        1
# 1.0L Turbo Inline-3 / 2.0L                         1
# 1.0L Turbo Inline-4                                1
# 1.0L Turbocharged Inline-3                         4
# 1.0L,INLINE-3                                      1
# 1.1L / 1.5L MIVEC                                  1
# 1.2L Diesel I3                                     3
# 1.2L Hybrid                                        1
# ...

# %%
index = df[df['Engines'].str.contains('/')]
# index.shape[0]
index
# Out:
#           Company Names                  Cars Names  \
# 271          Volkswagen                        Golf
# 275          Volkswagen                        Polo
# 279          Volkswagen                     Touareg
# 296          Volkswagen                     T-Cross
# 300          Volkswagen                    Multivan
# 309          Volkswagen                Golf Variant
# 311          Volkswagen                        Lupo
# 313          Volkswagen                     Phaeton
# 314          Volkswagen              Golf Cabriolet
# 316          Volkswagen                   Polo Vivo
# 318          Volkswagen                         Fox
# 319          Volkswagen                       Vento
# 321          Volkswagen                        Bora
# 322          Volkswagen                    Teramont
# 325          Volkswagen             T-Roc Cabriolet
# 330          Volkswagen                    Polo TDI
# 334          Volkswagen                   Passat B8
# ...

# %%
# df['CC/Battery Capacity'] = (
#     df['CC/Battery Capacity']
#     .str.replace('cc', '')
#     .str.replace('kWh', '')
#     .str.replace(',','').astype(float)
# )
