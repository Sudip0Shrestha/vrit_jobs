# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample data
data = {
    'datetime': pd.date_range(start='2026-01-01', periods=50, freq='M'),
    'year_months': [
'2026-01','2026-02','2026-03','2026-04','2026-05','2026-06','2026-07','2026-08','2026-09','2026-10',
'2026-11','2026-12','2027-01','2027-02','2027-03','2027-04','2027-05','2027-06','2027-07','2027-08',
'2027-09','2027-10','2027-11','2027-12','2028-01','2028-02','2028-03','2028-04','2028-05','2028-06',
'2028-07','2028-08','2028-09','2028-10','2028-11','2028-12','2029-01','2029-02','2029-03','2029-04',
'2029-05','2029-06','2029-07','2029-08','2029-09','2029-10','2029-11','2029-12','2030-01','2030-02'
],
    'sunspots': [23,45,12,67,34,56,44,38,29,60,52,48,30,41,55,62,37,46,58,33,
                 49,64,28,53,40,59,31,47,61,36,50,42,57,39,63,35,45,54,32,48,
                 60,41,56,34,52,38,47,59,36,44]
}

df = pd.DataFrame(data)

plt.figure(figsize = (10,6))
plt.subplot(1,2,1)
plt.xticks(rotation = 90)

plt.plot(df['datetime'], df['sunspots'], marker='o')

plt.subplot(1,2,2)
plt.plot(df['year_months'], df['sunspots'], marker='o')
plt.xticks(rotation = 90)


plt.tight_layout()
plt.show()
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_372\816259428.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   'datetime': pd.date_range(start='2026-01-01', periods=50, freq='M'),

# %%
df
# Out:
#     datetime year_months  sunspots
# 0 2026-01-31     2026-01        23
# 1 2026-02-28     2026-02        45
# 2 2026-03-31     2026-03        12
# 3 2026-04-30     2026-04        67
# 4 2026-05-31     2026-05        34
# 5 2026-06-30     2026-06        56
